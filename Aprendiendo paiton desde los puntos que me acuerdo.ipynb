# %% [markdown]
# <a href="https://colab.research.google.com/github/Angyinfor/Python-for-IA/blob/main/Aprendiendo%20paiton%20desde%20los%20puntos%20que%20me%20acuerdo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
para poder comentar en varias lineas es con 3 comillas dobles
para comentar con una sola linea es con un
para poder crear una varible en python
variable = "hello world"
los comentarios se pueden hacer tambien con snake case
"""

# %%
"""
Para poder imprimir en este caso de la
siguiente forma
"""
variable = "hello world"
print(variable)

# %%
"""
ahora para poder pedir informacion al user
tenemos que usar la declaracion input
"""
print ("welcome user")
name  = input("what's your name? ")
print ("your name is =", name)

# %%
"""
recordemos que existe tipos de datos
como lo es
*int
-los int son los numeros enteros
*string
-los string recordemos que son de tipo de texto
*float
-los flotantes son los numero ya sea enteros o decimales
*boleano
-los bool son los que son true or false (en español verdadero o falso)
recordemos que estas son las sencillas
"""

# %%
"""
Te preguntaras si exiten constantes en python
relativamente no existe pero podemos simular una constante
de la siguiente forma

VARIABLE = 3.1416

de desa forma poniendo las letras mayusculas pero al final del dia
sigue siendo una variable normal por que si lo imprimimos
VARIABLE = 3.1416
VARIABLE = 3.15151
print (VARIABLE)
con recordar que no podemos cabiar nuestra constante simulada
"""

# %%
"""
En python existen las opraciones relacionales cuales son las operaciones relacionales
son
(==): que tienen que ser iguales para que sea true
(!=): que los valores sean diferentes para que sea true
(>):para que el valor de la izquierda sea mayor que el de la derecha
(<):para que el valor de la izquierda sea menor que el de la derecha
(>=):para que el valor de la izquierda sea mayor o igual que el de la derecha
(<=):para que el valor de la izquierda sea menor o igual que el de la derecha
"""

# %%
"""
para poder pedir datos es necesario declarar primero la varible luego la sentencia
de la siguiente manera
"""
datos = input("coloca tu nombre aqui")
print (datos)
# Out:
# coloca tu nombre aquiname
# name

# %%
"""
vamos a hacer una pequña practica para pedir datos y que lo muestre
"""
nombre = input("to writhe here your name")
apellido  = input("coloca tu apellido aqui")
edad  = input("coloca tu edad aqui")
print(nombre, apellido, "con edad de ", edad)
# Out:
# to writhe here your nameangel
# coloca tu apellido aquimorales
# coloca tu edad aquiveinte
# angel  morales con edad de  veinte

# %%
"""
continuando podemos hacer una serie de lista
como una lista de cosas [papa, arroz, beans, chatrra]
ese ejemplo pues es lo que hace ser una lista tamnien existe
una lista de numero pero nomalmente son para
cosas como el anterior ejemplo
"""
alimentos = ["papa", "arroz", "beans", "chatrra"]
print(alimentos)

"""
es de la misma manera con os numeros cabe aclarar que los numeros
no llevan corchetes
"""
numeros = [1, 2, 3, 4, 5]
print(numeros)
# Out:
# ['papa', 'arroz', 'beans', 'chatrra']
# [1, 2, 3, 4, 5]

# %%
"""
para hacer el siguiente tipo tema son los inices
ok cuales son los indices (los indicies son aquellos numeros imaginarios que se presenran de la siguiente manera)

    0        1       2         3

["papa", "arroz", "beans", "chatrra"]
como el siguiente ejemplo lo vamos a hacer siempre sin importar cual se inicia desde el 0 y de ahi se desgloza para el contenido tenido


"""
